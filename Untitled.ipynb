# %%
import requests 
import pandas as pd

# %%
key = 'f2941a3b96cf342515290aed8576caffa54ca7cc00c3acf4e148527437a2b0a0'

rq_url = "https://api.peopledatalabs.com/v5/person/enrich"

test_params = {
    "api_key": key,
    "country":["United States"],
    "first_name": ["Dmitri"],
    "last_name": ["Mirakyan"],
    "region":["Texas"]
#     "location": ["7 Leroy Pl"],
}

def get_person():
    json_response = requests.get(rq_url,  params=test_params).json()
    return json_response

person = get_person()

# %%
person
# Out:
# {'status': 200,
#  'likelihood': 2,
#  'data': {'id': 'hEihKaIkWannmMruxR37lQ_0000',
#   'full_name': 'dmitri mirakyan',
#   'first_name': 'dmitri',
#   'middle_initial': None,
#   'middle_name': None,
#   'last_name': 'mirakyan',
#   'gender': 'male',
#   'birth_year': None,
#   'birth_date': None,
#   'linkedin_url': 'linkedin.com/in/dmirakyan',
#   'linkedin_username': 'dmirakyan',
#   'linkedin_id': None,
#   'facebook_url': 'facebook.com/damirakyan',
#   'facebook_username': 'damirakyan',
#   'facebook_id': '1523694271',
#   'twitter_url': None,
#   'twitter_username': None,
#   'github_url': None,
#   'github_username': None,
#   'work_email': None,
#   'mobile_phone': '+17134816998',
#   'industry': 'mechanical or industrial engineering',
#   'job_title': 'business operations associate',
#   'job_title_role': 'operations',
#   'job_title_levels': [],
#   'job_company_id': None,
#   'job_company_name': None,
#   'job_company_website': None,
#   'job_company_size': None,
#   'job_company_founded': None,
#   'job_company_industry': None,
#   'job_company_linkedin_url': None,
#   'job_company_linkedin_id': None,
#   'job_company_facebook_url': None,
#   'job_company_twitter_url': None,
#   'job_company_location_name': None,
#   'job_company_location_locality': None,
#   'job_company_location_region': None,
#   'job_company_location_geo': None,
#   'job_company_location_street_address': None,
#   'job_company_location_address_line_2': None,
#   'job_company_location_postal_code': None,
#   'job_company_location_country': None,
#   'job_company_location_continent': None,
#   'job_last_updated': '2020-05-01',
#   'location_name': 'san francisco, california, united states',
#   'location_locality': 'san francisco',
#   'location_region': 'california',
#   'location_country': 'united states',
#   'location_continent': 'north america',
#   'location_street_address': None,
#   'location_address_line_2': None,
#   'location_postal_code': None,
#   'location_geo': '37.77,-122.41',
#   'location_last_updated': '2020-05-01',
#   'phone_numbers': ['+17134816998'],
#   'emails': [{'address': 'dmitri.mirakyan@bractlet.com',
#     'type': 'professional'}],
#   'interests': [],
#   'skills': ['microsoft office',
#    'public speaking',
#    'teamwork',
#    'research',
#    'customer service',
#    'microsoft word',
#    'solidworks',
#    'matlab',
#    'microsoft excel',
#    'management',
#    'powerpoint',
#    'machine shop',
#    'indesign',
#    'magazine layout design',
#    'sql',
#    'sas programming',
#    'leadership',
#    'engineering',
#    'data analysis',
#    'autocad',
#    'microsoft powerpoint',
#    'data analytics',
#    'layout design'],
#   'location_names': ['moscow, moscow city, russia',
#    'irving, texas, united states',
#    'katy, texas, united states',
#    'houston, texas, united states',
#    'san francisco, california, united states'],
#   'regions': ['california, united states',
#    'moscow city, russia',
#    'texas, united states'],
#   'countries': ['russia', 'united states'],
#   'street_addresses': [{'name': 'irving, texas, united states',
#     'locality': 'irving',
#     'region': 'texas',
#     'country': 'united states',
#     'continent': 'north america',
#     'street_address': '2222 east grauwyler road',
#     'address_line_2': None,
#     'postal_code': '75061',
#     'geo': '32.81,-96.94'}],
#   'experience': [{'company': None,
#     'start_date': None,
#     'end_date': None,
#     'title': {'name': 'business operations associate',
#      'role': 'operations',
#      'levels': []},
#     'location_names': [],
#     'is_primary': True},
#    {'company': {'name': 'green revolution cooling',
#      'size': '11-50',
#      'id': 'green-revolution-cooling',
#      'founded': '2009',
#      'industry': 'computer hardware',
#      'location': {'name': 'austin, texas, united states',
#       'locality': 'austin',
#       'region': 'texas',
#       'country': 'united states',
#       'continent': 'north america',
#       'street_address': None,
#       'address_line_2': None,
#       'postal_code': None,
#       'geo': '30.26,-97.74'},
#      'linkedin_url': 'linkedin.com/company/green-revolution-cooling',
#      'linkedin_id': '1503981',
#      'facebook_url': 'facebook.com/greenrevolutioncooling',
#      'twitter_url': 'twitter.com/grcooling',
#      'website': 'grcooling.com'},
#     'start_date': '2016-11',
#     'end_date': '2017-05',
#     'title': {'name': 'mechanical engineering + marketing intern',
#      'role': 'engineering',
#      'levels': ['training']},
#     'location_names': [],
#     'is_primary': False},
#    {'company': {'name': 'deloitte',
#      'size': '10001+',
#      'id': 'deloitte',
#      'founded': '1900',
#      'industry': 'management consulting',
#      'location': {'name': 'new york, new york, united states',
#       'locality': 'new york',
#       'region': 'new york',
#       'country': 'united states',
#       'continent': 'north america',
#       'street_address': '30 rockefeller plaza',
#       'address_line_2': None,
#       'postal_code': '10112',
#       'geo': '40.71,-74.00'},
#      'linkedin_url': 'linkedin.com/company/deloitte',
#      'linkedin_id': '1038',
#      'facebook_url': 'facebook.com/deloitte',
#      'twitter_url': 'twitter.com/deloitte',
#      'website': 'deloitte.com'},
#     'location_names': [],
#     'end_date': None,
#     'start_date': '2017-07',
#     'title': {'name': 'business technology analyst',
#      'role': 'operations',
#      'levels': []},
#     'is_primary': False},
#    {'company': {'name': 'the university of texas at austin',
#      'size': '10001+',
#      'id': 'theuniversityoftexasataustin-',
#      'founded': '1883',
#      'industry': 'higher education',
#      'location': {'name': 'austin, texas, united states',
#       'locality': 'austin',
#       'region': 'texas',
#       'country': 'united states',
#       'continent': 'north america',
#       'street_address': '1 university station',
#       'address_line_2': None,
#       'postal_code': '78712',
#       'geo': '30.26,-97.74'},
#      'linkedin_url': 'linkedin.com/company/theuniversityoftexasataustin-',
#      'linkedin_id': '3162',
#      'facebook_url': 'facebook.com/utmccombsschool',
#      'twitter_url': 'twitter.com/txventurelabs',
#      'website': 'utexas.edu'},
#     'location_names': ['austin, texas, united states'],
#     'end_date': '2015-06',
#     'start_date': '2014-08',
#     'title': {'name': 'student classroom support technician',
#      'role': 'customer_service',
#      'levels': []},
#     'is_primary': False},
#    {'company': {'name': 'capital one',
#      'size': '10001+',
#      'id': 'capital-one',
#      'founded': '1994',
#      'industry': 'financial services',
#      'location': {'name': 'mclean, virginia, united states',
#       'locality': 'mclean',
#       'region': 'virginia',
#       'country': 'united states',
#       'continent': 'north america',
#       'street_address': '1680 capital one drive',
#       'address_line_2': None,
#       'postal_code': '22102',
#       'geo': '38.93,-77.17'},
#      'linkedin_url': 'linkedin.com/company/capital-one',
#      'linkedin_id': '1419',
#      'facebook_url': None,
#      'twitter_url': 'twitter.com/capitalone',
#      'website': 'capitalone.com'},
#     'location_names': ['plano, texas, united states'],
#     'end_date': '2016-08',
#     'start_date': '2016-06',
#     'title': {'name': 'business analyst intern',
#      'role': 'operations',
#      'levels': ['training']},
#     'is_primary': False},
#    {'company': {'name': 'bractlet',
#      'size': '11-50',
#      'id': 'bractlet',
#      'founded': '2011',
#      'industry': 'mechanical or industrial engineering',
#      'location': {'name': 'austin, texas, united states',
#       'locality': 'austin',
#       'region': 'texas',
#       'country': 'united states',
#       'continent': 'north america',
#       'street_address': '510 south congress avenue',
#       'address_line_2': 'suite 107',
#       'postal_code': '78704',
#       'geo': '30.26,-97.74'},
#      'linkedin_url': 'linkedin.com/company/bractlet',
#      'linkedin_id': '9584793',
#      'facebook_url': None,
#      'twitter_url': 'twitter.com/bractlet',
#      'website': 'bractlet.com'},
#     'location_names': ['austin, texas, united states'],
#     'end_date': '2016-05',
#     'start_date': '2015-06',
#     'title': {'name': 'hardware development intern',
#      'role': None,
#      'levels': ['training']},
#     'is_primary': False}],
#   'education': [{'school': {'name': 'cinco ranch high school',
#      'type': 'secondary school',
#      'id': None,
#      'location': None,
#      'linkedin_url': None,
#      'facebook_url': None,
#      'twitter_url': None,
#      'linkedin_id': None,
#      'website': None,
#      'domain': None},
#     'degrees': [],
#     'start_date': None,
#     'end_date': None,
#     'majors': [],
#     'minors': [],
#     'gpa': None},
#    {'school': {'name': 'the university of texas at austin',
#      'type': 'post-secondary institution',
#      'id': 'e1c7924c-fa11-4f5b-b20c-6784c6ba8568',
#      'location': {'name': 'austin, texas, united states',
#       'locality': 'austin',
#       'region': 'texas',
#       'country': 'united states',
#       'continent': 'north america'},
#      'linkedin_url': 'linkedin.com/school/theuniversityoftexasataustin-',
#      'facebook_url': None,
#      'twitter_url': None,
#      'linkedin_id': '19518',
#      'website': 'utexas.edu',
#      'domain': 'utexas.edu'},
#     'end_date': '2017',
#     'start_date': '2013',
#     'gpa': None,
#     'degrees': ['bachelors', 'bachelor of science'],
#     'majors': ['mechanical engineering'],
#     'minors': []}],
#   'profiles': [{'network': 'linkedin',
#     'id': '180422547',
#     'url': 'linkedin.com/in/dmitri-mirakyan-24350b50',
#     'username': 'dmitri-mirakyan-24350b50'},
#    {'network': 'facebook',
#     'id': '1523694271',
#     'url': 'facebook.com/damirakyan',
#     'username': 'damirakyan'},
#    {'network': 'linkedin',
#     'id': None,
#     'url': 'linkedin.com/in/dmirakyan',
#     'username': 'dmirakyan'}],
#   'version_status': {'status': 'updated',
#    'contains': [],
#    'previous_version': '10',
#    'current_version': '11'}},
#  'dataset_version': '11.0'}
